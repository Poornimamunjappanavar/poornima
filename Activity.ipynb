# %% [markdown]
# <a href="https://colab.research.google.com/github/Poornimamunjappanavar/poornima/blob/main/Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df =pd.read_csv('/content/tips.csv')
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Bar plot of total tips per day
sns.barplot(x="day", y="tip", data=tips)

plt.title("Total Tips by Day")
plt.xlabel("Day of Week")
plt.ylabel("Total Tip Amount ($)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.displot(tips["tip"], kde=True, bins=20)
plt.title("Distribution of Tips")
plt.xlabel("Tip Amount ($)")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as pl
sns.countplot(x="sex", data=tips)
plt.title("Proportion of Male vs Female Customers")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="total_bill", y="tip", hue="sex", data=tips)
plt.title("Association between Total Bill and Tip")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
sns.lineplot(x=tips.index, y="tip", data=tips)
plt.title("Time Series of Tips")
plt.show()

# %%
import pandas as pd
df =pd.read_csv('/content/penguins.csv')
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen            39.1           18.7              181.0
# 1      2  Adelie  Torgersen            39.5           17.4              186.0
# 2      3  Adelie  Torgersen            40.3           18.0              195.0
# 3      4  Adelie  Torgersen             NaN            NaN                NaN
# 4      5  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x="species", y="body_mass_g", data=df, estimator="mean")

plt.title("Average Body Mass of Penguins by Species")
plt.xlabel("Species")
plt.ylabel("Body Mass (g)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
penguins = penguins.dropna()
sns.displot(data=penguins, x="bill_length_mm", hue="species", kind="kde", fill=True)
plt.title("Distribution of Bill Length by Species")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=penguins, x="species")
plt.title("Proportion of Penguins by Species")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="flipper_length_mm", y="body_mass_g", hue="species", data=penguins)
plt.title("Association between Flipper Length and Body Mass")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x=penguins.index, y="body_mass_g", data=penguins)
plt.title("Simulated Time Series of Penguin Body Mass")
plt.xlabel("Index (as Time)")
plt.ylabel("Body Mass (g)")
plt.show()
