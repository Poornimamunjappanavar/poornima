# %% [markdown]
# <a href="https://colab.research.google.com/github/Poornimamunjappanavar/poornima/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
x=df[['mpg']]
x
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [398 rows x 1 columns]

# %%
y=df[['origin']]
y
# Out:
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 393       1
# 394       2
# 395       1
# 396       1
# 397       1
#
# [398 rows x 1 columns]

# %%
sns.scatterplot(x=df['mpg'], y=df['origin'])
# Out:
# <Axes: xlabel='mpg', ylabel='origin'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_test
# Out:
#       mpg
# 47   19.0
# 58   25.0
# 132  25.0
# 98   16.0
# 104  12.0
# ..    ...
# 242  21.5
# 105  13.0
# 202  17.5
# 141  29.0
# 270  21.1
#
# [80 rows x 1 columns]

# %%
x_train
# Out:
#       mpg
# 46   22.0
# 82   23.0
# 115  15.0
# 283  20.2
# 30   28.0
# ..    ...
# 10   15.0
# 100  18.0
# 195  29.0
# 379  36.0
# 135  18.0
#
# [318 rows x 1 columns]

# %%
y_train
# Out:
#      origin
# 46        1
# 82        3
# 115       1
# 283       1
# 30        1
# ..      ...
# 10        1
# 100       1
# 195       1
# 379       1
# 135       1
#
# [318 rows x 1 columns]

# %%
y_test
# Out:
#      origin
# 47        1
# 58        1
# 132       1
# 98        1
# 104       1
# ..      ...
# 242       2
# 105       1
# 202       1
# 141       2
# 270       3
#
# [80 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
Y_pred=lr.predict(x_test)
print('y_pred',Y_pred)
# Out:
# y_pred [[1.31682963]
#  [1.65450477]
#  [1.65450477]
#  [1.14799205]
#  [0.92287529]
#  [2.46492512]
#  [2.58311142]
#  [1.59822558]
#  [1.26055043]
#  [2.07097078]
#  [1.42938801]
#  [1.46315552]
#  [1.23803876]
#  [1.76706315]
#  [1.40124841]
#  [1.93590073]
#  [1.65450477]
#  [0.92287529]
#  [0.81031691]
#  [1.4856672 ]
#  [1.37310882]
#  [1.67701645]
#  [1.42938801]
#  [2.08785454]
#  [1.03543367]
#  [1.71078396]
#  [1.20427124]
#  [1.50255096]
#  [1.99217992]
#  [1.50817887]
#  [1.14799205]
#  [1.09171286]
#  [2.34673882]
#  [2.02031951]
#  [1.09171286]
#  [0.92287529]
#  [1.93590073]
#  [2.00906367]
#  [1.37310882]
#  [2.36925049]
#  [1.26617835]
#  [1.31682963]
#  [2.38613425]
#  [1.75580731]
#  [1.71078396]
#  [1.20427124]
#  [1.59822558]
#  [1.81771442]
#  [1.31682963]
#  [1.76706315]
#  [1.99217992]
#  [2.04845911]
#  [1.20427124]
#  [1.82334234]
#  [1.76706315]
#  [1.11985246]
#  [1.59822558]
#  [0.92287529]
#  [1.57008598]
#  [0.97915448]
#  [2.16101749]
#  [1.14799205]
#  [1.93590073]
#  [2.27357587]
#  [1.59822558]
#  [1.87962153]
#  [1.23241084]
#  [1.14799205]
#  [1.09171286]
#  [1.54194639]
#  [1.23803876]
#  [0.97915448]
#  [1.65450477]
#  [1.03543367]
#  [1.54194639]
#  [1.4575276 ]
#  [0.97915448]
#  [1.23241084]
#  [1.87962153]
#  [1.43501593]]

# %%
y_test
# Out:
#      origin
# 47        1
# 58        1
# 132       1
# 98        1
# 104       1
# ..      ...
# 242       2
# 105       1
# 202       1
# 141       2
# 270       3
#
# [80 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
mse = mean_squared_error(y_test, Y_pred)
mae = mean_absolute_error(y_test, Y_pred)
r1 = r2_score(y_test, Y_pred)

# %%
import numpy as np
rsme=np.sqrt(mse)
print(rsme)
# Out:
# 0.6091523655537981

# %%
print('mean squared error',mse)
print('mean absolute error',mae)
print('r2_score',r1)
print('rmse',rsme)
# Out:
# mean squared error 0.3710666044597881
# mean absolute error 0.47830362503824464
# r2_score 0.3789680260087229
# rmse 0.6091523655537981

# %%
plt.scatter(x_train,y_train,color='green')
y_train_pred = lr.predict(x_train)
plt.plot(x_train,y_train_pred,color='red')
plt.title('mpg vs origin(training set)')
plt.xlabel('mpg')
plt.ylabel('origin')
plt.show()
